# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats as st
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from loguru import logger
from yellowbrick.model_selection import RFECV
# Out:
# c:\users\marin.desktop-jcc1rh5\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Algumas configurações para o matplotlib.
# %matplotlib inline
from IPython.core.pylabtools import figsize
figsize(12, 8)
sns.set()

# %%
fifa = pd.read_csv("fifa.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    fifa.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")
# Out:
# 2020-07-17 13:27:48.804 | WARNING  | __main__:<module>:14 - Columns already dropped

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
print("----------Top-5- Record----------")
print(fifa.head(5))
print("-----------Information-----------")
print(fifa.info())
print("-----------Data Types-----------")
print(fifa.dtypes)
print("----------Missing value-----------")
print(fifa.isnull().sum())
print("----------Null value-----------")
print(fifa.isna().sum())
print("----------Shape of Data----------")
print(fifa.shape)
# Out:
# ----------Top-5- Record----------
#    Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0   31       94         94      84.0       95.0             70.0
# 1   33       94         94      84.0       94.0             89.0
# 2   26       92         93      79.0       87.0             62.0
# 3   27       91         93      17.0       13.0             21.0
# 4   27       91         92      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 0          90.0     86.0       97.0   93.0  ...       75.0       96.0
# 1          81.0     87.0       88.0   81.0  ...       85.0       95.0
# 2          84.0     84.0       96.0   88.0  ...       81.0       94.0
# 3          50.0     13.0       18.0   21.0  ...       40.0       68.0
# 4          92.0     82.0       86.0   85.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 37 columns]
# -----------Information-----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              18207 non-null  int64
#  1   Overall          18207 non-null  int64
#  2   Potential        18207 non-null  int64
#  3   Crossing         18159 non-null  float64
#  4   Finishing        18159 non-null  float64
#  5   HeadingAccuracy  18159 non-null  float64
#  6   ShortPassing     18159 non-null  float64
#  7   Volleys          18159 non-null  float64
#  8   Dribbling        18159 non-null  float64
#  9   Curve            18159 non-null  float64
#  10  FKAccuracy       18159 non-null  float64
#  11  LongPassing      18159 non-null  float64
#  12  BallControl      18159 non-null  float64
#  13  Acceleration     18159 non-null  float64
#  14  SprintSpeed      18159 non-null  float64
#  15  Agility          18159 non-null  float64
#  16  Reactions        18159 non-null  float64
#  17  Balance          18159 non-null  float64
#  18  ShotPower        18159 non-null  float64
#  19  Jumping          18159 non-null  float64
#  20  Stamina          18159 non-null  float64
#  21  Strength         18159 non-null  float64
#  22  LongShots        18159 non-null  float64
#  23  Aggression       18159 non-null  float64
#  24  Interceptions    18159 non-null  float64
#  25  Positioning      18159 non-null  float64
#  26  Vision           18159 non-null  float64
#  27  Penalties        18159 non-null  float64
#  28  Composure        18159 non-null  float64
#  29  Marking          18159 non-null  float64
#  30  StandingTackle   18159 non-null  float64
#  31  SlidingTackle    18159 non-null  float64
#  32  GKDiving         18159 non-null  float64
#  33  GKHandling       18159 non-null  float64
#  34  GKKicking        18159 non-null  float64
#  35  GKPositioning    18159 non-null  float64
#  36  GKReflexes       18159 non-null  float64
# dtypes: float64(34), int64(3)
# memory usage: 5.1 MB
# None
# -----------Data Types-----------
# Age                  int64
# Overall              int64
# Potential            int64
# Crossing           float64
# Finishing          float64
# HeadingAccuracy    float64
# ShortPassing       float64
# Volleys            float64
# Dribbling          float64
# Curve              float64
# FKAccuracy         float64
# LongPassing        float64
# BallControl        float64
# Acceleration       float64
# SprintSpeed        float64
# Agility            float64
# Reactions          float64
# Balance            float64
# ShotPower          float64
# Jumping            float64
# Stamina            float64
# Strength           float64
# LongShots          float64
# Aggression         float64
# Interceptions      float64
# Positioning        float64
# Vision             float64
# Penalties          float64
# Composure          float64
# Marking            float64
# StandingTackle     float64
# SlidingTackle      float64
# GKDiving           float64
# GKHandling         float64
# GKKicking          float64
# GKPositioning      float64
# GKReflexes         float64
# dtype: object
# ----------Missing value-----------
# Age                 0
# Overall             0
# Potential           0
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# GKDiving           48
# GKHandling         48
# GKKicking          48
# GKPositioning      48
# GKReflexes         48
# dtype: int64
# ----------Null value-----------
# Age                 0
# Overall             0
# Potential           0
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# GKDiving           48
# GKHandling         48
# GKKicking          48
# GKPositioning      48
# GKReflexes         48
# dtype: int64
# ----------Shape of Data----------
# (18207, 37)

# %%
# Sua análise começa aqui.
# Remover linhas com valores faltantes
fifa.dropna(axis=0, how='any',inplace=True)

# %%
fifa.head(5)
# Out:
#    Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0   31       94         94      84.0       95.0             70.0
# 1   33       94         94      84.0       94.0             89.0
# 2   26       92         93      79.0       87.0             62.0
# 3   27       91         93      17.0       13.0             21.0
# 4   27       91         92      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 0          90.0     86.0       97.0   93.0  ...       75.0       96.0
# 1          81.0     87.0       88.0   81.0  ...       85.0       95.0
# 2          84.0     84.0       96.0   88.0  ...       81.0       94.0
# 3          50.0     13.0       18.0   21.0  ...       40.0       68.0
# 4          92.0     82.0       86.0   85.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 37 columns]

# %%
fifa_pivot = pd.DataFrame({'columns': fifa.columns,
                           'types': fifa.dtypes,
                           'nulls': fifa.isna().sum(),
                           '% nulls': fifa.isna().sum() / fifa.shape[0],
                           'size': fifa.shape[0],
                           'uniques': fifa.nunique()})
fifa_pivot
# Out:
#                          columns    types  nulls  % nulls   size  uniques
# Age                          Age    int64      0      0.0  18159       29
# Overall                  Overall    int64      0      0.0  18159       48
# Potential              Potential    int64      0      0.0  18159       47
# Crossing                Crossing  float64      0      0.0  18159       89
# Finishing              Finishing  float64      0      0.0  18159       93
# HeadingAccuracy  HeadingAccuracy  float64      0      0.0  18159       91
# ShortPassing        ShortPassing  float64      0      0.0  18159       85
# Volleys                  Volleys  float64      0      0.0  18159       87
# Dribbling              Dribbling  float64      0      0.0  18159       94
# Curve                      Curve  float64      0      0.0  18159       89
# FKAccuracy            FKAccuracy  float64      0      0.0  18159       90
# LongPassing          LongPassing  float64      0      0.0  18159       84
# BallControl          BallControl  float64      0      0.0  18159       90
# Acceleration        Acceleration  float64      0      0.0  18159       86
# SprintSpeed          SprintSpeed  float64      0      0.0  18159       85
# Agility                  Agility  float64      0      0.0  18159       81
# Reactions              Reactions  float64      0      0.0  18159       68
# Balance                  Balance  float64      0      0.0  18159       81
# ShotPower              ShotPower  float64      0      0.0  18159       92
# Jumping                  Jumping  float64      0      0.0  18159       74
# Stamina                  Stamina  float64      0      0.0  18159       85
# Strength                Strength  float64      0      0.0  18159       74
# LongShots              LongShots  float64      0      0.0  18159       92
# Aggression            Aggression  float64      0      0.0  18159       85
# Interceptions      Interceptions  float64      0      0.0  18159       89
# Positioning          Positioning  float64      0      0.0  18159       94
# Vision                    Vision  float64      0      0.0  18159       85
# Penalties              Penalties  float64      0      0.0  18159       87
# Composure              Composure  float64      0      0.0  18159       84
# Marking                  Marking  float64      0      0.0  18159       92
# StandingTackle    StandingTackle  float64      0      0.0  18159       90
# SlidingTackle      SlidingTackle  float64      0      0.0  18159       88
# GKDiving                GKDiving  float64      0      0.0  18159       71
# GKHandling            GKHandling  float64      0      0.0  18159       70
# GKKicking              GKKicking  float64      0      0.0  18159       79
# GKPositioning      GKPositioning  float64      0      0.0  18159       79
# GKReflexes            GKReflexes  float64      0      0.0  18159       76

# %%
fifa_pivot['% nulls'].plot.hist(bins=5)

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
def q1():
    pca = PCA().fit(fifa)
    return float(pca.explained_variance_ratio_[0].round(3))

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
def q2():
    pca = PCA(n_components=0.95)
    fifa_reduced = pca.fit_transform(fifa)
    return fifa_reduced.shape[1]

# %%
pca = PCA().fit(fifa)
evr = pca.explained_variance_ratio_

# %%
g = sns.lineplot(np.arange(len(evr)), np.cumsum(evr))
g.axes.axhline(0.95, ls="--", color="red")
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %%
def q3():
    pca = PCA(n_components=2).fit(fifa)
    return tuple(pca.components_.dot(x).round(3))

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
regression = LinearRegression()

X = fifa.drop(columns='Overall')
y = fifa['Overall']

# %%
def q4():
    rfe = RFE(regression, n_features_to_select=5)
    rfe = rfe.fit(X, y)
    return list(X.loc[:, rfe.support_].columns)

# %%
visualizer = RFECV(regression)
visualizer.fit(X, y)
visualizer.show()
# Out:
# c:\users\marin.desktop-jcc1rh5\miniconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# c:\users\marin.desktop-jcc1rh5\miniconda3\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
